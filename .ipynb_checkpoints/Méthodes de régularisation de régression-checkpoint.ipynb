# %% [markdown]
# # La méthode Lasso

# %%
#importer vos libs 
import warnings
warnings.simplefilter("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline 
from sklearn import linear_model #modèle linéaire
from sklearn.metrics import mean_squared_error, r2_score #métriques d'évaluation

# %%
# Charger les données
houses = pd.read_csv("./house_data.csv", sep=",")

# Sélectionner les colonnes à afficher
colonnes_afficher = ['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot']

# Renommer les colonnes pour correspondre à l'image
houses = houses[colonnes_afficher]
# Afficher les premières lignes du DataFrame
print(houses.head())
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot
# 0      5650
# 1      7242
# 2     10000
# 3      5000
# 4      8080

# %%
# Afficher la dimension du DataFrame( ligne, colonnes)
#print the sample of the dataset
print(houses.shape)
# Out:
# (21613, 7)

# %%
import seaborn as sns

# %%
# Sélectionner les colonnes d'intérêt 
colonnes_interet = ['sqft_lot', 'date', 'price', 'sqft_living', 'bedrooms'] 
houses = houses[colonnes_interet]

# %%
# Utiliser Seaborn pour tracer le pairplot
sns.pairplot(houses, hue='bedrooms')
plt.show()
